# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~!
#
# "Challenge : 사칙연산을 이용해 문제 풀기"는 잘 풀어보셨나요?
#
#
# 너~~무 어려웠어요! 하는 분들을 위해 만들어봤습니다!
#
# 문제 도장깨기 !!!!!
#
# 차근차근 풀어나가면 파이썬 정복 가능입니다!
#
# 화이팅 !
#
# Chapter04의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# <br/>
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
#
# <br>
# <br>
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>
# <br>

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# -----

# %% [markdown]
# <br>
#
# __[문제1]__
#
# 한 상자에 사과가 7개 들어있습니다.
#
# 사과가 많이 먹고 싶어서 3개의 상자를 구입했습니다!
#
# 총 사과의 개수를 계산해주세요.
#
#
# <br>

# %%
box=7
total=box*3
print(total)
# Out:
# 21

# %% [markdown]
# <br>
#
# __[문제2]__
#
# 영화 티켓 한 장의 가격은 10,000원입니다.
#
# 친구 한명이 로또에 당첨되서 티켓을 사준다고 합니다!
#
# 4명의 친구가 각각 4장씩 구매할 때, 총 가격이 어떻게 되는지 계산해주세요
#
# <br>

# %%
ticket=10000
total=4*4*ticket
print(total)
# Out:
# 160000

# %% [markdown]
# <br>
#
# __[문제3]__
#
# 지각입니다 !!!!!
#
# 지하철을 타고 5개의 역이 남았습니다.
#
# 각 역은 3분씩 걸립니다. 시간을 계산해볼 수 있도록 5개의 역을 지나는데 걸린 총 시간을 구해주세요.

# %%
left_station=5
station_time=3
total_time=left_station*station_time
print(total_time)
# Out:
# 15

# %% [markdown]
# <br>__[문제4]__
#
# 파이썬 기초 관련 책이 9권 있습니다.
#
# 오즈코딩스쿨을 통해 파이썬을 마스터 해버려서 필요없습니다.
#
# 책을 3명의 친구에게 똑같이 나눠줄 때, 각 사람에게 몇 권씩 나누어줄 수 있을까요?

# %%
python_basic_book=9
give_book=3
each_book=python_basic_book//give_book
print(each_book)
# Out:
# 3

# %% [markdown]
# __[문제5]__
#
# 무인도에 2명의 갇혀있습니다.
#
# 가진건 초콜릿 8개뿐,,
#
# 각 사람은 초콜릿을 몇 개씩 먹을 수 있을까요?

# %%
no_one_island=2
chocolate=8
can_eat_chocolate=chocolate//no_one_island
print(can_eat_chocolate)
# Out:
# 4

# %% [markdown]
# <br>
#
# __[문제6]__
#
# 한 변의 길이가 5인 정사각형이 있습니다.
#
# 정사각형의 넓이를 구하세요.
# <br>

# %%
line_length=5
square_extent=line_length*line_length
print(square_extent)
# Out:
# 25
